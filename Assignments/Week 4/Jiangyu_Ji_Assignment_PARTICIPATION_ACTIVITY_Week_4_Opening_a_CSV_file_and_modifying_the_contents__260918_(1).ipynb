# %% [markdown]
# <a href="https://colab.research.google.com/github/asteriaji/MSSP6070/blob/main/Assignments/Week%204/Jiangyu_Ji_Assignment_PARTICIPATION_ACTIVITY_Week_4_Opening_a_CSV_file_and_modifying_the_contents__260918_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv

with open('/content/drive/MyDrive/MSSP 6070/a.  Assignments/Week 4/parsed.csv', encoding='UTF-8') as f:
    reader = csv.reader(f)
    data = list(reader)

# %%
data[0]
# Out:
# ['alert',
#  'cdi',
#  'code',
#  'detail',
#  'dmin',
#  'felt',
#  'gap',
#  'ids',
#  'mag',
#  'magType',
#  'mmi',
#  'net',
#  'nst',
#  'place',
#  'rms',
#  'sig',
#  'sources',
#  'status',
#  'time',
#  'title',
#  'tsunami',
#  'type',
#  'types',
#  'tz',
#  'updated',
#  'url',
#  'parsed_place']

# %%
# 2.a.
import pandas as pd
df = pd.DataFrame(data[1:], columns=data[0])
df.info()
percentile_95 = df[(df['parsed_place'] == 'Japan') & (df['magType'] == 'mb')]['mag'].astype(float).quantile(0.95)
print('The 95th percentile of earthquake magnitude in Japan for earthquakes with a magnitude type of mb is',percentile_95)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9332 entries, 0 to 9331
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   alert         9332 non-null   object
#  1   cdi           9332 non-null   object
#  2   code          9332 non-null   object
#  3   detail        9332 non-null   object
#  4   dmin          9332 non-null   object
#  5   felt          9332 non-null   object
#  6   gap           9332 non-null   object
#  7   ids           9332 non-null   object
#  8   mag           9332 non-null   object
#  9   magType       9332 non-null   object
#  10  mmi           9332 non-null   object
#  11  net           9332 non-null   object
#  12  nst           9332 non-null   object
#  13  place         9332 non-null   object
#  14  rms           9332 non-null   object
#  15  sig           9332 non-null   object
#  16  sources       9332 non-null   object
#  17  status        9332 non-null   object
# ...

# %%
# 2.b.
indonesia_number = df[df['parsed_place'] == 'Indonesia']
percentage = indonesia_number['tsunami'].value_counts()['1'] / len(indonesia_number) * 100
print('The percentage of earthquakes in Indonesia that were coupled with tsunamis is', percentage)
# Out:
# The percentage of earthquakes in Indonesia that were coupled with tsunamis is 23.12925170068027

# %%
# 2.c.
numeric_cols = ['cdi', 'dmin', 'felt', 'gap', 'mag', 'mmi', 'nst', 'rms', 'sig', 'time', 'tsunami', 'tz', 'updated']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
Nevada = df[df['place'].str.contains('Nevada', na=False)]
Nevada.describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  677.000000  15.000000  677.000000  677.000000  1.00
# mean    2.440000    0.166982   2.400000  154.029527    0.491728  2.84
# std     0.501142    0.166400   4.626013   68.769713    0.689560   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.054000   1.000000   97.670000   -0.100000  2.84
# 50%     2.200000    0.113000   1.000000  149.550000    0.400000  2.84
# 75%     2.900000    0.234000   1.000000  200.470000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  677.000000  677.000000  677.000000  6.770000e+02    677.0  677.0
# mean    12.608567    0.151909   10.688331  1.538314e+12      0.0 -480.0
# std      9.890620    0.084742   19.252727  5.954070e+08      0.0    0.0
# ...

# %%
# 2.d.
df['ring_of_fire'] = df['parsed_place'].str.contains(
    r'|'.join([
        'Bolivia', 'Chile', 'Ecuador', 'Peru', 'Costa Rica',
        'Guatemala', '^Mexico', 'Japan', 'Philippines', 'Indonesia',
        'New Zealand', 'Antarctic', 'Canada', 'Fiji',
        'Alaska', 'Washington', 'California', 'Russia',
        'Taiwan', 'Tonga', 'Kermadec Islands']),
    regex=True,
    na=False)
df
# Out:
#      alert  cdi        code  \
# 0           NaN    37389218
# 1           NaN    37389202
# 2           4.4    37389194
# 3           NaN    37389186
# 4           NaN    73096941
# ...    ...  ...         ...
# 9327        NaN    73086771
# 9328        NaN    38063967
# 9329        NaN  2018261000
# 9330        NaN    38063959
# 9331        NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
# 2.e.
in_ring_of_fire_number = df[
    (df['ring_of_fire'] == True) &
    (df['type'] == 'earthquake')
]

print('The number of earthquakes in the Ring of Fire locations is', len(in_ring_of_fire_number))

not_in_ring_of_fire_number = df[
    (df['ring_of_fire'] == False) &
    (df['type'] == 'earthquake')
]

print('The number of earthquakes in the Ring of Fire locations is', len(not_in_ring_of_fire_number))
# Out:
# The number of earthquakes in the Ring of Fire locations is 7004
# The number of earthquakes in the Ring of Fire locations is 2077

# %%
# 2.f.
tsunami_ring_of_fire = df[(df['ring_of_fire'] == True) & (df['tsunami'] == 1)]
print(len(tsunami_ring_of_fire))
# Out:
# 45
